# %% [markdown]
# # 03. 상호작용 지도 만들기

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import pandas as pd
import geopandas as gpd
import math

# %%
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %% [markdown]
# ## 간단한 상호작용 지도 만들기

# %%
m_1 = folium.Map(location=[42.32, -71.0589], tiles='openstreetmap', zoom_start=10)

m_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a378c5cd73829d2ea4f7c2aba2eda7db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a378c5cd73829d2ea4f7c2aba2eda7db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a378c5cd73829d2ea4f7c2aba2eda7db = L.map(
#                 &quot;map_a378c5cd73829d2ea4f7c2aba2eda7db&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c70e397c16bf0af97934e6a07789a70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6c70e397c16bf0af97934e6a07789a70.addTo(map_a378c5cd73829d2ea4f7c2aba2eda7db);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 범죄 데이터 불러오기

# %%
# load the data
crimes = pd.read_csv('C:/Users/GBOOK/PythonGeoSpatialAnalysis/archive/crimes-in-boston/crimes-in-boston/crime.csv', encoding='latin-1')

# Drop rows with missing location
crimes.dropna(subset=['Lat', 'Long', 'DISTRICT'], inplace=True)

# Focus on Major crimes in 2018
crimes = crimes[crimes.OFFENSE_CODE_GROUP.isin([
    'Larceny', 'Auto Theft', 'Robbery', 'Larceny From Motor Vehicle', 'Residential Burglary',
    'Simple Assault', 'Harassment', 'Ballistics', 'Aggravated Assault', 'Other Burglary', 
    'Arson', 'Commercial Burglary', 'HOME INVASION', 'Homicide', 'Criminal Harassment', 
    'Manslaughter'])]
crimes = crimes[crimes.YEAR >= 2018]

# Print First Five rows of the table
crimes.head()
# Out:
#    INCIDENT_NUMBER  OFFENSE_CODE          OFFENSE_CODE_GROUP  \
# 0       I182070945           619                     Larceny
# 6       I182070933           724                  Auto Theft
# 8       I182070931           301                     Robbery
# 19      I182070915           614  Larceny From Motor Vehicle
# 24      I182070908           522        Residential Burglary
#
#                       OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0                      LARCENY ALL OTHERS      D14            808      NaN
# 6                              AUTO THEFT       B2            330      NaN
# 8                        ROBBERY - STREET       C6            177      NaN
# 19  LARCENY THEFT FROM MV - NON-ACCESSORY       B2            181      NaN
# 24      BURGLARY - RESIDENTIAL - NO FORCE       B2            911      NaN
#
#        OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART  \
# 0   2018-09-02 13:00:00  2018      9      Sunday    13  Part One
# 6   2018-09-03 21:25:00  2018      9      Monday    21  Part One
# 8   2018-09-03 20:48:00  2018      9      Monday    20  Part One
# 19  2018-09-02 18:00:00  2018      9      Sunday    18  Part One
# 24  2018-09-03 18:38:00  2018      9      Monday    18  Part One
#
#                STREET        Lat       Long                     Location
# 0          LINCOLN ST  42.357791 -71.139371  (42.35779134, -71.13937053)
# 6         NORMANDY ST  42.306072 -71.082733  (42.30607218, -71.08273260)
# 8   MASSACHUSETTS AVE  42.331521 -71.070853  (42.33152148, -71.07085307)
# 19         SHIRLEY ST  42.325695 -71.068168  (42.32569490, -71.06816778)
# 24    ANNUNCIATION RD  42.335062 -71.093168  (42.33506218, -71.09316781)

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15682 entries, 0 to 318868
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INCIDENT_NUMBER      15682 non-null  object
#  1   OFFENSE_CODE         15682 non-null  int64
#  2   OFFENSE_CODE_GROUP   15682 non-null  object
#  3   OFFENSE_DESCRIPTION  15682 non-null  object
#  4   DISTRICT             15682 non-null  object
#  5   REPORTING_AREA       15682 non-null  object
#  6   SHOOTING             110 non-null    object
#  7   OCCURRED_ON_DATE     15682 non-null  object
#  8   YEAR                 15682 non-null  int64
#  9   MONTH                15682 non-null  int64
#  10  DAY_OF_WEEK          15682 non-null  object
#  11  HOUR                 15682 non-null  int64
#  12  UCR_PART             15666 non-null  object
#  13  STREET               15647 non-null  object
#  14  Lat                  15682 non-null  float64
#  15  Long                 15682 non-null  float64
#  16  Location             15682 non-null  object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 2.2+ MB

# %% [markdown]
# ## 포인트 데이터 그리기
# 지도에 표현되는 데이터의 양을 줄이기 위해 주간시간대 9-18시 사이에 일어나는 강도범죄들만 표현

# %%
# daytime_robberies = crimes[((crimes.OFFENSE_CODE_GROUP == 'Robbery') & (crimes.HOUR.isin(range(9, 18))))]
daytime_robberies = crimes[((crimes.OFFENSE_CODE_GROUP == 'Robbery') & \
                            (crimes.HOUR.isin(range(9,18))))]

# %%
daytime_robberies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 231 entries, 299 to 181223
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INCIDENT_NUMBER      231 non-null    object
#  1   OFFENSE_CODE         231 non-null    int64
#  2   OFFENSE_CODE_GROUP   231 non-null    object
#  3   OFFENSE_DESCRIPTION  231 non-null    object
#  4   DISTRICT             231 non-null    object
#  5   REPORTING_AREA       231 non-null    object
#  6   SHOOTING             1 non-null      object
#  7   OCCURRED_ON_DATE     231 non-null    object
#  8   YEAR                 231 non-null    int64
#  9   MONTH                231 non-null    int64
#  10  DAY_OF_WEEK          231 non-null    object
#  11  HOUR                 231 non-null    int64
#  12  UCR_PART             231 non-null    object
#  13  STREET               231 non-null    object
#  14  Lat                  231 non-null    float64
#  15  Long                 231 non-null    float64
#  16  Location             231 non-null    object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 32.5+ KB

# %% [markdown]
# ## folium Marker 표현하기

# %%
# Create a map
m_2 = folium.Map(location=[42.32, -71.0589], tiles='cartodbpositron', zoom_start=13)

# Add points to the map
for idx, row in daytime_robberies.iterrows():
    Marker([row['Lat'], row['Long']]).add_to(m_2)
    
# Display
m_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1b7fa7e21274a9d46fe8196c6699ad8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1b7fa7e21274a9d46fe8196c6699ad8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1b7fa7e21274a9d46fe8196c6699ad8 = L.map(
#                 &quot;map_d1b7fa7e21274a9d46fe8196c6699ad8&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2914d22d9e0c05e746e8f648917ca2e7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2914d22d9e0c05e746e8f648917ca2e7.addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_2e7342497f3de0c2b3b618562fd5613d = L.marker(
#                 [42.37167264, -71.06326413],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_9e0441c86a4b7b8eed1ceebf32857073 = L.marker(
#                 [42.27645319, -71.11297971],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_5c1173ffb3cbf028d593b162dae89a13 = L.marker(
#                 [42.3460551, -71.07050669],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_3cb431a215b3666a2e37d7c22cac73e9 = L.marker(
#                 [42.36219081, -71.06223802],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_73179787c66861087486bcdc67f9ae67 = L.marker(
#                 [42.33153805, -71.08015661],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_17e774dce2cbf65bd4fe1479204e843c = L.marker(
#                 [42.30492239, -71.10298073],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_e7c4b1c07043550f71489f10c15b270f = L.marker(
#                 [42.32624204, -71.10317575],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_dddf389277a3f6c49b75883955f27dfb = L.marker(
#                 [42.24894017, -71.12130622],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_9f3227c27641f4e8627065bd84b60c13 = L.marker(
#                 [42.332354, -71.07138696],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_4074809be24289acf09633b494f17ebe = L.marker(
#                 [42.29623685, -71.04853645],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_9baddcc32bf7b70f5c1b66af02ce2568 = L.marker(
#                 [42.35521625, -71.06012863],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_89d6da67677873bba6de5e355b032070 = L.marker(
#                 [42.3524587, -71.13762608],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_db84614bdea3f30d7886b5da6807c5ba = L.marker(
#                 [42.32277007, -71.10445458],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_fd98020285bf865acd30b9737e9106ce = L.marker(
#                 [42.35327561, -71.06345772],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_3923d3393894a7978cdd34df18d67cfc = L.marker(
#                 [42.35602373, -71.06177615],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_b7de9cd3696d32d7a80739b70a938e24 = L.marker(
#                 [42.35331987, -71.06102314],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_967783eebbbe835d408411feb806440e = L.marker(
#                 [42.2752767, -71.09554245],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_cbefb0d08f1d54dd8a31bac9a4006897 = L.marker(
#                 [42.30803768, -71.08359213],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_e77beca4543033bb242fb2491ea72e43 = L.marker(
#                 [42.35218278, -71.0556788],
#                 {}
#             ).addTo(map_d1b7fa7e21274a9d46fe8196c6699ad8);
#
#
#             var marker_b15f5ed8f730d98c986dd33cc6342afa = L.marker(
#                 [42.35255981, -71.06043207],
#                 {}
#             ).add

# %% [markdown]
# ## MarkerCluster

# %%
m_3 = folium.Map(location=[42.32, -71.0859], tiles='cartodbpositron', zoom_start=13)

mc = MarkerCluster()
for idx, row in daytime_robberies.iterrows():
    if not math.isnan(row['Long']) and not math.isnan(row['Lat']):
        mc.add_child(Marker([row['Lat'], row['Long']]))
m_3.add_child(mc)

m_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7690f58a7ba9ecf2a7c58629178a754 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7690f58a7ba9ecf2a7c58629178a754&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7690f58a7ba9ecf2a7c58629178a754 = L.map(
#                 &quot;map_a7690f58a7ba9ecf2a7c58629178a754&quot;,
#                 {
#                     center: [42.32, -71.0859],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92a91c0393446e8933c463c82d38237c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_92a91c0393446e8933c463c82d38237c.addTo(map_a7690f58a7ba9ecf2a7c58629178a754);
#
#
#             var marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_3f51eefb8fcc77fef6935d74f85a710a = L.marker(
#                 [42.37167264, -71.06326413],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_e9dc9eef4fcf813fe0183e8c7c3ba859 = L.marker(
#                 [42.27645319, -71.11297971],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_a6241a6134ee3b8035a0ba09756a6dcb = L.marker(
#                 [42.3460551, -71.07050669],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_06d88b2def09b5ae68a755c3600d30e8 = L.marker(
#                 [42.36219081, -71.06223802],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_7fe6899942c748794107a78ec2a21312 = L.marker(
#                 [42.33153805, -71.08015661],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_eccea094963a4c57c999c18533d42ebe = L.marker(
#                 [42.30492239, -71.10298073],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_fb96410a92b4fdd47b07805507b1ffd4 = L.marker(
#                 [42.32624204, -71.10317575],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_94abab26dc780553974ccb7fe07c9d2d = L.marker(
#                 [42.24894017, -71.12130622],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_c33b0a7adc2c6f98ab3d42d498ba08f9 = L.marker(
#                 [42.332354, -71.07138696],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_41e699b2723ec91fbe924ad321f8e1d0 = L.marker(
#                 [42.29623685, -71.04853645],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_db1bafba9b7e0f8de246899ffe1e5a91 = L.marker(
#                 [42.35521625, -71.06012863],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_b5fee4a74f1c29491962664c3f7f1f3c = L.marker(
#                 [42.3524587, -71.13762608],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_bc167571d604ca9c759f791fde60b698 = L.marker(
#                 [42.32277007, -71.10445458],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_c55b9af9201c9de4d3e5e360c6403d73 = L.marker(
#                 [42.35327561, -71.06345772],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_1f813df90febe3930d984009f9b1346d = L.marker(
#                 [42.35602373, -71.06177615],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);
#
#
#             var marker_44faddce66f17247284354eb1e028315 = L.marker(
#                 [42.35331987, -71.06102314],
#                 {}
#             ).addTo(marker_cluster_ebfee9ee3e6f8b1f460c2036718604f6);

# %% [markdown]
# ## Bubble Map

# %%
m_4 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=13)

def color_producer(val):
    if val <= 12:
        return 'forestgreen'
    else:
        return 'darkred'
    
for i in range(0, len(daytime_robberies)):
    Circle(
        location=[daytime_robberies.iloc[i]['Lat'], daytime_robberies.iloc[i]['Long']],
        radius=20,
        color=color_producer(daytime_robberies.iloc[i]['HOUR'])
    ).add_to(m_4)
    
m_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4b7956166c9ac4078f118499c4c4355 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4b7956166c9ac4078f118499c4c4355&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4b7956166c9ac4078f118499c4c4355 = L.map(
#                 &quot;map_d4b7956166c9ac4078f118499c4c4355&quot;,
#                 {
#                     center: [42.32, -71.0589],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c24361cf5f0f68dad7302c9a23d8c01 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0c24361cf5f0f68dad7302c9a23d8c01.addTo(map_d4b7956166c9ac4078f118499c4c4355);
#
#
#             var circle_0df51b94fd3360b0c91eee6b88ccee91 = L.circle(
#                 [42.37167264, -71.06326413],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d4b7956166c9ac4078f118499c4c4355);
#
#
#             var circle_eeb5d825fb2908c3a93586f9f9948cee = L.circle(
#                 [42.27645319, -71.11297971],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d4b7956166c9ac4078f118499c4c4355);
#
#
#             var circle_ee7b3cb2a98d957a6b677a175928c6ad = L.circle(
#                 [42.3460551, -71.07050669],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d4b7956166c9ac4078f118499c4c4355);
#
#
#             var circle_c782bb8b0dccc525a019044502267e9f = L.circle(
#                 [42.36219081, -71.06223802],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d4b7956166c9ac4078f118499c4c4355);
#
#
#             var circle_7abe2b4fc1c24c691f63345dfe15acaf = L.circle(
#                 [42.33153805, -71.08015661],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;forestgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;forestgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d4b7956166c9ac4078f118499c4c4355);
#
#
#             var circle_a530af6e9f0ee52229159dd3753b7bee = L.circle(
#                 [42.30492239, -71.10298073],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d4b7956166c9ac4078f118499c4c4355);
#
#
#             var circle_2eb92374b6661dcf615eb4c12db728
